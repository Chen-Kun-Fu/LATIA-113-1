# %%
def hello():
  print('hello')

# %%
hello()
# Out:
# hello

# %%
def hello(msg):
  print(msg)
hello('hello')
hello('good morning')
# Out:
# hello
# good morning

# %%
def hello(x,y=10):
  z=x+y
  print(z)
hello(1,)
# Out:
# 11

# %%
def hello(name,age):
  msg = f'{name}is {age} years old'
  print(msg)
hello(123,10)
# Out:
# 123is 10 years old

# %%
def a(x,y):
  result = x + y*2
  return result
b=a(1,2)
c=a(2,3)
print(b,c)
# Out:
# 5 8

# %%
def a(x):
  result=0
  while result < 10:
    result = result + x
    if result==5:
      return result
  return result
b = a(1)
c = a(2)
print(b,c)
# Out:
# 5 10

# %%
def tf(value):
  return 2*value-1
test_values = [0.0, 0.0011, 0.25, 0.5,0,54, 0.75, 1.0]
scaled_values = [tf(value) for value in test_values]
print("Original values: ", test_values)
print("Scaled values: ", scaled_values)
# Out:
# Original values:  [0.0, 0.0011, 0.25, 0.5, 0, 54, 0.75, 1.0]
# Scaled values:  [-1.0, -0.9978, -0.5, 0.0, -1, 107, 0.5, 1.0]

# %%
def a(n):
  if n==0 or n==1:
    return 1
  else:
    return n+a(n-1)

print(a(3))
# Out:
# 6

# %%
with open('test.txt','w') as f1:
  f1.write('good morning')

# %%
import datetime
print(datetime.datetime.now())
print(datetime.date.today())
# Out:
# 2024-09-26 08:56:49.062525
# 2024-09-26

# %%
import datetime as dd
print(dd.datetime.now())
print(dd.date.today())
# Out:
# 2024-09-26 08:58:18.068059
# 2024-09-26

# %%
import numpy as np
import pandas as pd

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates,
columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.540304  0.293927 -0.440054  0.040707
# 2013-01-02  0.294225  1.211355 -1.577059  1.760428
# 2013-01-03  0.872265  0.669092  1.429620  1.022644
# 2013-01-04  0.276828  1.795608  1.025196  0.589142
# 2013-01-05  0.577731 -0.241061  1.179348  1.099521
# 2013-01-06  1.573207  0.753368 -0.820943 -0.884739

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  1.789258  2.163921  0.126819  0.653858
# 2013-01-02  0.837353  2.033348  1.057086  0.236954
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755
# 2013-01-04  0.089449  0.344173  0.013594  0.046071
# 2013-01-05  0.684296  0.569823 -0.334175  1.009897

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.089449  0.344173  0.013594  0.046071
# 2013-01-05  0.684296  0.569823 -0.334175  1.009897
# 2013-01-06  1.254281 -2.265864  1.187392 -0.425719

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df2 = df.copy()
df2.to_numpy()
# Out:
# array([[ 1.78925767,  2.16392071,  0.12681891,  0.65385775],
#        [ 0.83735279,  2.03334829,  1.05708621,  0.23695404],
#        [ 0.89333897, -0.14289826, -1.07360493, -0.41275461],
#        [ 0.08944947,  0.34417322,  0.01359419,  0.04607125],
#        [ 0.68429634,  0.56982307, -0.33417453,  1.00989666],
#        [ 1.25428123, -2.26586393,  1.18739194, -0.42571943]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.924663  0.450417  0.162852  0.184718
# std    0.569234  1.624655  0.854257  0.574904
# min    0.089449 -2.265864 -1.073605 -0.425719
# 25%    0.722560 -0.021130 -0.247232 -0.298048
# 50%    0.865346  0.456998  0.070207  0.141513
# 75%    1.164046  1.667467  0.824519  0.549632
# max    1.789258  2.163921  1.187392  1.009897

# %%
q=df.describe()
q
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.924663  0.450417  0.162852  0.184718
# std    0.569234  1.624655  0.854257  0.574904
# min    0.089449 -2.265864 -1.073605 -0.425719
# 25%    0.722560 -0.021130 -0.247232 -0.298048
# 50%    0.865346  0.456998  0.070207  0.141513
# 75%    1.164046  1.667467  0.824519  0.549632
# max    1.789258  2.163921  1.187392  1.009897

# %%
df3=df.T
df3
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.789258    0.837353    0.893339    0.089449    0.684296    1.254281
# B    2.163921    2.033348   -0.142898    0.344173    0.569823   -2.265864
# C    0.126819    1.057086   -1.073605    0.013594   -0.334175    1.187392
# D    0.653858    0.236954   -0.412755    0.046071    1.009897   -0.425719

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.789258  2.163921  0.126819  0.653858
# 2013-01-02  0.837353  2.033348  1.057086  0.236954
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755
# 2013-01-04  0.089449  0.344173  0.013594  0.046071
# 2013-01-05  0.684296  0.569823 -0.334175  1.009897
# 2013-01-06  1.254281 -2.265864  1.187392 -0.425719

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.789258  2.163921  0.126819  0.653858
# 2013-01-02  0.837353  2.033348  1.057086  0.236954
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755
# 2013-01-04  0.089449  0.344173  0.013594  0.046071
# 2013-01-05  0.684296  0.569823 -0.334175  1.009897
# 2013-01-06  1.254281 -2.265864  1.187392 -0.425719

# %%
df3=df.T
df3
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.789258    0.837353    0.893339    0.089449    0.684296    1.254281
# B    2.163921    2.033348   -0.142898    0.344173    0.569823   -2.265864
# C    0.126819    1.057086   -1.073605    0.013594   -0.334175    1.187392
# D    0.653858    0.236954   -0.412755    0.046071    1.009897   -0.425719

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.789258    0.837353    0.893339    0.089449    0.684296    1.254281
# B    2.163921    2.033348   -0.142898    0.344173    0.569823   -2.265864
# C    0.126819    1.057086   -1.073605    0.013594   -0.334175    1.187392
# D    0.653858    0.236954   -0.412755    0.046071    1.009897   -0.425719

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.789258  2.163921  0.126819  0.653858
# 2013-01-02  0.837353  2.033348  1.057086  0.236954
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755
# 2013-01-04  0.089449  0.344173  0.013594  0.046071
# 2013-01-05  0.684296  0.569823 -0.334175  1.009897
# 2013-01-06  1.254281 -2.265864  1.187392 -0.425719

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.653858  0.126819  2.163921  1.789258
# 2013-01-02  0.236954  1.057086  2.033348  0.837353
# 2013-01-03 -0.412755 -1.073605 -0.142898  0.893339
# 2013-01-04  0.046071  0.013594  0.344173  0.089449
# 2013-01-05  1.009897 -0.334175  0.569823  0.684296
# 2013-01-06 -0.425719  1.187392 -2.265864  1.254281

# %%
df["A"]
# Out:
# 2013-01-01    1.789258
# 2013-01-02    0.837353
# 2013-01-03    0.893339
# 2013-01-04    0.089449
# 2013-01-05    0.684296
# 2013-01-06    1.254281
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  1.789258  2.163921  0.126819  0.653858
# 2013-01-02  0.837353  2.033348  1.057086  0.236954
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755

# %%
for dfp in df.loc[dates[0]]:
  for dfq in df.loc[:, ["A", "B"]]:
    for r in df.loc["20130102":"20130104", ["A", "B"]]:
      for s in df.loc["20130102":"20130104", ["A", "B"]]:
# Out:
# 1.789257666392677
# 1.789257666392677
# 1.789257666392677
# 1.789257666392677
# 1.789257666392677
# 1.789257666392677
# 1.789257666392677
# 1.789257666392677
# 2.163920711807239
# 2.163920711807239
# 2.163920711807239
# 2.163920711807239
# 2.163920711807239
# 2.163920711807239
# 2.163920711807239
# 2.163920711807239
# 0.12681891123875688
# 0.12681891123875688
# 0.12681891123875688
# 0.12681891123875688
# 0.12681891123875688
# 0.12681891123875688
# 0.12681891123875688
# 0.12681891123875688
# 0.6538577521034717
# 0.6538577521034717
# 0.6538577521034717
# 0.6538577521034717
# 0.6538577521034717
# 0.6538577521034717
# 0.6538577521034717
# 0.6538577521034717

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  0.837353  2.033348
# 2013-01-03  0.893339 -0.142898
# 2013-01-04  0.089449  0.344173

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755   two
# 2013-01-05  0.684296  0.569823 -0.334175  1.009897  four

# %%
df2 = df.copy()

df2[df2 > 0] = -df2

df2
# Out:
#                    A         B         C         D
# 2013-01-01 -1.789258 -2.163921 -0.126819 -0.653858
# 2013-01-02 -0.837353 -2.033348 -1.057086 -0.236954
# 2013-01-03 -0.893339 -0.142898 -1.073605 -0.412755
# 2013-01-04 -0.089449 -0.344173 -0.013594 -0.046071
# 2013-01-05 -0.684296 -0.569823 -0.334175 -1.009897
# 2013-01-06 -1.254281 -2.265864 -1.187392 -0.425719

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.789258  2.163921  0.126819  0.653858  1.0
# 2013-01-02  0.837353  2.033348  1.057086  0.236954  1.0
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755  NaN
# 2013-01-04  0.089449  0.344173  0.013594  0.046071  NaN

# %%
df1.dropna( )
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.789258  2.163921  0.126819  0.653858  1.0
# 2013-01-02  0.837353  2.033348  1.057086  0.236954  1.0

# %%
df1.fillna(5)
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.789258  2.163921  0.126819  0.653858  1.0
# 2013-01-02  0.837353  2.033348  1.057086  0.236954  1.0
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755  5.0
# 2013-01-04  0.089449  0.344173  0.013594  0.046071  5.0

# %%
df1.interpolate( )
# Out:
#                    A         B         C         D    E
# 2013-01-01  1.789258  2.163921  0.126819  0.653858  1.0
# 2013-01-02  0.837353  2.033348  1.057086  0.236954  1.0
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755  1.0
# 2013-01-04  0.089449  0.344173  0.013594  0.046071  1.0

# %%
df.mean()
# Out:
# A    0.924663
# B    0.450417
# C    0.162852
# D    0.184718
# dtype: float64

# %%
df.std()
# Out:
# A    0.569234
# B    1.624655
# C    0.854257
# D    0.574904
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.183464
# 2013-01-02    1.041185
# 2013-01-03   -0.183980
# 2013-01-04    0.123322
# 2013-01-05    0.482460
# 2013-01-06   -0.062478
# Freq: D, dtype: float64

# %%
df.std(axis = 1)
# Out:
# 2013-01-01    0.953111
# 2013-01-02    0.746765
# 2013-01-03    0.817736
# 2013-01-04    0.150478
# 2013-01-05    0.575457
# 2013-01-06    1.661614
# Freq: D, dtype: float64

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.789258  2.163921  0.126819  0.653858
# 2013-01-02  0.837353  2.033348  1.057086  0.236954
# 2013-01-03  0.893339 -0.142898 -1.073605 -0.412755
# 2013-01-04  0.089449  0.344173  0.013594  0.046071
# 2013-01-05  0.684296  0.569823 -0.334175  1.009897
# 2013-01-06  1.254281 -2.265864  1.187392 -0.425719

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.789258  2.163921  0.126819  0.653858
# 2013-01-02  0.837353  2.033348  1.057086  0.236954
# 2013-01-03  0.893339       NaN       NaN       NaN
# 2013-01-04  0.089449  0.344173  0.013594  0.046071
# 2013-01-05  0.684296  0.569823       NaN  1.009897
# 2013-01-06  1.254281       NaN  1.187392       NaN
