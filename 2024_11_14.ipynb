# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100) # 產生 0~10 總共 100 連續數字
y = 4 + 2 * np.sin(2 * x) # 使用 NumPy 的廣播方式,產生 sin 數值的陣列 y

fig, ax = plt.subplots()
ax.plot(x, y, linewidth=2.0) # 繪製折線圖

ax.set(xlim=(0, 8), xticks=np.arange(1, 8), # 設定座標軸
ylim=(0, 8), yticks=np.arange(1, 8))

plt.show() # 顯示圖表

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import os
image = img.imread('aa.jpg')
plt.figure(figsize=(10,10)) # 改變圖表尺寸
plt.imshow(image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-d99a888dd493> in <cell line: 4>()
#       2 import matplotlib.image as img
#       3 import os
# ----> 4 image = img.imread('aa.jpg')
#       5 plt.figure(figsize=(10,10)) # 改變圖表尺寸
#       6 plt.imshow(image)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imread(fname, format)
#    1523             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1524             )
# -> 1525     with img_open(fname) as image:
#    1526         return (_pil_png_to_float_array(image)
#    1527                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3467
#    3468     if filename:
# -> 3469         fp = builtins.open(filename, "rb")
#    3470         exclusive_fp = True
#    3471     else:
# ...

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(projection='3d') # 設定為 3D 圖表
x = range(5)
y = [1,5,8,4,6]
ax.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
# 畫出顏色紅色、圓形錨點、虛線、粗細 2、資料點大小 6 的線條
#plt.plot(x,color='r', marker='o', linewidth=2, markersize=6)
plt.plot(x)
plt.show()

# %%
import numpy as np
import pandas as pd
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates,
columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.912753 -0.795342  1.319620  0.039823
# 2013-01-02 -1.778426 -1.319857 -0.533308 -0.090535
# 2013-01-03  0.051853  0.771642  1.007581  0.763921
# 2013-01-04 -0.365773 -0.548473 -0.044224  1.791098
# 2013-01-05  1.673375 -0.876331  1.319314 -0.284574
# ...              ...       ...       ...       ...
# 2013-04-06 -1.018924 -1.967418 -2.860775 -0.379327
# 2013-04-07 -0.152680  1.834573  0.843856  1.612906
# 2013-04-08  0.555384  0.917624  3.008685 -0.045734
# 2013-04-09  0.599109 -1.644219  0.881552  1.008396
# 2013-04-10  0.853573  0.459225 -0.201721 -0.982339
#
# [100 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

x = []
# 畫出顏色紅色、圓形錨點、虛線、粗細 2、資料點大小 6 的線條
plt.plot(x,color='r', marker='o', linewidth=2, markersize=6)
#plt.plot(x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3ecfc59f8af7> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 x = A
#       4 # 畫出顏色紅色、圓形錨點、虛線、粗細 2、資料點大小 6 的線條
#       5 plt.plot(x,color='r', marker='o', linewidth=2, markersize=6)
#
# NameError: name 'A' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame with random data and dates
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# Plot data from column 'A' with the specified style
plt.plot(df.index, df['A'], color='r', marker='o', linestyle='--', linewidth=2, markersize=6)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
h = [10,20,30,40,50]
color = ['r','b','g','y','m'] # 顏色數據
label = ['a','b','c','d','e'] # 標籤數據
plt.bar(x,h,color=color,tick_label=label,width=0.5) # 加入顏色、標籤
和寬度參數
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4f4a9f40139a> in <cell line: 7>()
#       5 label = ['a','b','c','d','e'] # 標籤數據
#       6 plt.bar(x,h,color=color,tick_label=label,width=0.5) # 加入顏色、標籤
# ----> 7 和寬度參數
#       8 plt.show()
#
# NameError: name '和寬度參數' is not defined

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
plt.pie(x, radius=1.5, labels=x)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(projection='3d')
x = [2,4,6,8,10]
y = 10
z = 1
ax.bar3d(x,y,z,dx=1,dy=1,dz=[1,2,3,4,5])
plt.show()

# %%
import numpy as np
import pandas as pd
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 使用 pandas 自帶的繪圖功能
df.plot(figsize=(10, 6))  # 設置圖形大小

# 顯示圖表
plt.title('Random Data for Columns A, B, C, D')  # 設置標題
plt.xlabel('Date')  # 設置 x 軸標籤
plt.ylabel('Value')  # 設置 y 軸標籤
plt.grid(True)  # 顯示網格
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 繪製長條圖
df.mean().plot(kind='bar', figsize=(10, 6), color=['r', 'b', 'g', 'y'])

# 設置標題和標籤
plt.title('Average Value of Columns A, B, C, D')
plt.xlabel('Columns')
plt.ylabel('Average Value')
plt.xticks(rotation=0)  # x軸標籤水平顯示
plt.grid(True)

# 顯示圖表
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 計算每列的平均值
mean_values = df.mean()

# 繪製圓餅圖
mean_values.plot(kind='pie', figsize=(8, 8), autopct='%1.1f%%', colors=['r', 'b', 'g', 'y'])

# 設置標題
plt.title('Average Value Distribution of Columns A, B, C, D')

# 顯示圖表
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-95944449f783> in <cell line: 13>()
#      11
#      12 # 繪製圓餅圖
# ---> 13 mean_values.plot(kind='pie', figsize=(8, 8), autopct='%1.1f%%', colors=['r', 'b', 'g', 'y'])
#      14
#      15 # 設置標題
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      68                 ax = plt.gca()
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71     plot_obj.generate()
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 計算每列的平均值
mean_values = df.mean()

# 將負值轉換為正值或使用絕對值
# Option 1: 使用絕對值
mean_values = abs(mean_values)
# Option 2: 將負值轉換為0
# mean_values[mean_values < 0] = 0

# 繪製圓餅圖
mean_values.plot(kind='pie', figsize=(8, 8), autopct='%1.1f%%', colors=['r', 'b', 'g', 'y'])

# 設置標題
plt.title('Average Value Distribution of Columns A, B, C, D')

# 顯示圖表
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 繪製每列的柱狀圖
df.mean().plot(kind='bar', figsize=(10, 6), color=['r', 'b', 'g', 'y'])

# 設置標題和標籤
plt.title('Average Value Distribution of Columns A, B, C, D')
plt.xlabel('Columns')
plt.ylabel('Average Value')

# 顯示圖表
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 創建3D圖形
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 設置 x、y、z 軸的數據
x = np.arange(len(df))  # 日期的索引作為 x 軸
y = np.arange(df.shape[1])  # 列索引（A, B, C, D）作為 y 軸
x, y = np.meshgrid(x, y)  # 創建網格

# Z 軸數據（即每個位置的值）
z = np.zeros_like(x)

# 條形的高度
dx = np.ones_like(z)  # x 軸方向的條形寬度
dy = np.ones_like(z)  # y 軸方向的條形寬度
dz = df.values.T  # 每列的數據轉置為每個條形的高度

# 繪製 3D 條形圖
ax.bar3d(x.flatten(), y.flatten(), z.flatten(), dx.flatten(), dy.flatten(), dz.flatten(), color='b', zsort='average')

# 設置標題和軸標籤
ax.set_title('3D Bar Chart of Random Data')
ax.set_xlabel('Date')
ax.set_ylabel('Columns (A, B, C, D)')
ax.set_zlabel('Value')

# 設置 y 軸的刻度標籤為 A, B, C, D
ax.set_yticks(np.arange(df.shape[1]))
ax.set_yticklabels(df.columns)

# 顯示圖形
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 創建3D圖形
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 設置 x、y、z 軸的數據
x = np.arange(len(df))  # 日期的索引作為 x 軸
y = np.arange(df.shape[1])  # 列索引（A, B, C, D）作為 y 軸
x, y = np.meshgrid(x, y)  # 創建網格

# Z 軸數據（即每個位置的值）
z = np.zeros_like(x)

# 條形的高度
dx = np.ones_like(z)  # x 軸方向的條形寬度
dy = np.ones_like(z)  # y 軸方向的條形寬度
dz = df.values.T  # 每列的數據轉置為每個條形的高度

# 根據 dz 值設置顏色
# 使用 colormap 來根據數值的大小選擇顏色
norm = plt.Normalize(dz.min(), dz.max())  # 標準化數據以匹配 colormap
colors = plt.cm.viridis(norm(dz.flatten()))  # 使用 viridis colormap，並且基於 dz 數值調整顏色

# 繪製 3D 條形圖
ax.bar3d(x.flatten(), y.flatten(), z.flatten(), dx.flatten(), dy.flatten(), dz.flatten(), color=colors, zsort='average')

# 設置標題和軸標籤
ax.set_title('3D Bar Chart of Random Data with Color')
ax.set_xlabel('Date')
ax.set_ylabel('Columns (A, B, C, D)')
ax.set_zlabel('Value')

# 設置 y 軸的刻度標籤為 A, B, C, D
ax.set_yticks(np.arange(df.shape[1]))
ax.set_yticklabels(df.columns)

# 顯示顏色條（顏色映射）
mappable = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
mappable.set_array(dz.flatten())
fig.colorbar(mappable, ax=ax, shrink=0.5, aspect=5)

# 顯示圖形
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 創建3D圖形
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 設置 x、y、z 軸的數據
x = np.arange(len(df))  # 日期的索引作為 x 軸
y = np.arange(df.shape[1])  # 列索引（A, B, C, D）作為 y 軸
x, y = np.meshgrid(x, y)  # 創建網格

# Z 軸數據（即每個位置的值）
z = np.zeros_like(x)

# 條形的高度
dx = np.ones_like(z)  # x 軸方向的條形寬度
dy = np.ones_like(z)  # y 軸方向的條形寬度
dz = df.values.T  # 每列的數據轉置為每個條形的高度

# 根據列名設置顏色
colors = ['r', 'g', 'b', 'y']  # 為 A, B, C, D 分配顏色，分別是紅色、綠色、藍色、黃色

# 繪製 3D 條形圖
for i in range(df.shape[1]):
    ax.bar3d(x.flatten(), np.full_like(y.flatten(), i), z.flatten(), dx.flatten(), dy.flatten(), dz[i].flatten(), color=colors[i], zsort='average')

# 設置標題和軸標籤
ax.set_title('3D Bar Chart of Random Data with Column-Based Colors')
ax.set_xlabel('Date')
ax.set_ylabel('Columns (A, B, C, D)')
ax.set_zlabel('Value')

# 設置 y 軸的刻度標籤為 A, B, C, D
ax.set_yticks(np.arange(df.shape[1]))
ax.set_yticklabels(df.columns)

# 顯示圖形
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-7502b810f772> in <cell line: 31>()
#      30 # 繪製 3D 條形圖
#      31 for i in range(df.shape[1]):
# ---> 32     ax.bar3d(x.flatten(), np.full_like(y.flatten(), i), z.flatten(), dx.flatten(), dy.flatten(), dz[i].flatten(), color=colors[i], zsort='average')
#      33
#      34 # 設置標題和軸標籤
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/mplot3d/axes3d.py in bar3d(self, x, y, z, dx, dy, dz, color, zsort, shade, lightsource, *args, **kwargs)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 創建3D圖形
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 設置 x、y、z 軸的數據
x = np.arange(len(df))  # 日期的索引作為 x 軸
y = np.arange(df.shape[1])  # 列索引（A, B, C, D）作為 y 軸
x, y = np.
# Out:
#   File "<ipython-input-26-f951faf046eb>", line 17
#     x, y = np.
#               ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 創建3D圖形
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 設置 x、y、z 軸的數據
x = np.arange(len(df))  # 日期的索引作為 x 軸
y = np.arange(df.shape[1])  # 列索引（A, B, C, D）作為 y 軸
x, y = np.meshgrid(x, y)  # 創建網格

# Z 軸數據（即每個位置的值）
z = np.zeros_like(x)

# 條形的高度
dx = np.ones_like(z)  # x 軸方向的條形寬度
dy = np.ones_like(z)  # y 軸方向的條形寬度
dz = df.values.T  # 每列的數據轉置為每個條形的高度

# 顏色設置：根據列名設置顏色
colors = ['r', 'g', 'b', 'y']  # 為 A, B, C, D 分配顏色，分別是紅色、綠色、藍色、黃色

# 繪製 3D 條形圖
for i in range(df.shape[1]):  # 循環處理每一列（A, B, C, D）
    ax.bar3d(x.flatten(), np.full_like(y.flatten(), i), z.flatten(), dx.flatten(), dy.flatten(), dz[i].flatten(), color=colors[i], zsort='average')

# 設置標題和軸標籤
ax.set_title('3D Bar Chart of Random Data with Column-Based Colors')
ax.set_xlabel('Date')
ax.set_ylabel('Columns (A, B, C, D)')
ax.set_zlabel('Value')

# 設置 y 軸的刻度標籤為 A, B, C, D
ax.set_yticks(np.arange(df.shape[1]))
ax.set_yticklabels(df.columns)

# 顯示圖形
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-840806bae28c> in <cell line: 31>()
#      30 # 繪製 3D 條形圖
#      31 for i in range(df.shape[1]):  # 循環處理每一列（A, B, C, D）
# ---> 32     ax.bar3d(x.flatten(), np.full_like(y.flatten(), i), z.flatten(), dx.flatten(), dy.flatten(), dz[i].flatten(), color=colors[i], zsort='average')
#      33
#      34 # 設置標題和軸標籤
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/mplot3d/axes3d.py in bar3d(self, x, y, z, dx, dy, dz, color, zsort, shade, lightsource, *args, **kwargs)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 創建3D圖形
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 設置 x、y、z 軸的數據
x = np.arange(len(df))  # 日期的索引作為 x 軸
y = np.arange(df.shape[1])  # 列索引（A, B, C, D）作為 y 軸
x, y = np.meshgrid(x, y)  # 創建網格

# Z 軸數據（即每個位置的值）
z = np.zeros_like(x)

# 條形的高度
dx = np.ones_like(z)  # x 軸方向的條形寬度
dy = np.ones_like(z)  # y 軸方向的條形寬度
dz = df.values.T  # 每列的數據轉置為每個條形的高度

# 顏色設置：根據列名設置顏色
colors = ['r', 'g', 'b', 'y']  # 為 A, B, C, D 分配顏色，分別是紅色、綠色、藍色、黃色

# 繪製 3D 條形圖
for i in range(df.shape[1]):  # 循環處理每一列（A, B, C, D）
    ax.bar3d(x.flatten(), np.full_like(y.flatten(), i), z.flatten(), dx.flatten(), dy.flatten(), dz[i].flatten(), color=colors[i], zsort='average')

# 設置標題和軸標籤
ax.set_title('3D Bar Chart of Random Data with Column-Based Colors')
ax.set_xlabel('Date')
ax.set_ylabel('Columns (A, B, C, D)')
ax.set_zlabel('Value')

# 設置 y 軸的刻度標籤為 A, B, C, D
ax.set_yticks(np.arange(df.shape[1]))
ax.set_yticklabels(df.columns)

# 顯示圖形
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-840806bae28c> in <cell line: 31>()
#      30 # 繪製 3D 條形圖
#      31 for i in range(df.shape[1]):  # 循環處理每一列（A, B, C, D）
# ---> 32     ax.bar3d(x.flatten(), np.full_like(y.flatten(), i), z.flatten(), dx.flatten(), dy.flatten(), dz[i].flatten(), color=colors[i], zsort='average')
#      33
#      34 # 設置標題和軸標籤
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/mplot3d/axes3d.py in bar3d(self, x, y, z, dx, dy, dz, color, zsort, shade, lightsource, *args, **kwargs)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 生成日期範圍和隨機數據
dates = pd.date_range("20130101", periods=100)
df = pd.DataFrame(np.random.randn(100, 4), index=dates, columns=list("ABCD"))

# 創建3D圖形
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 設置 x、y、z 軸的數據
x = np.arange(len(df))  # 日期的索引作為 x 軸
y = np.arange(df.shape[1])  # 列索引（A, B, C, D）作為 y 軸

# Z 軸數據（即每個位置的值）
z = np.zeros_like(x)  # 初始的 Z 軸位置是 0

# 條形的高度
dx = np.ones_like(z)  # x 軸方向的條形寬度
dy = np.ones_like(z)  # y 軸方向的條形寬度
dz = df.values.T  # 每列的數據轉置為每個條形的高度

# 顏色設置：根據列名分配顏色
colors = ['r', 'g', 'b', 'y']  # 為 A, B, C, D 分配不同顏色

# 繪製 3D 條形圖
for i in range(df.shape[1]):  # 循環繪製每一列數據
    ax.bar3d(x, np.full_like(x, i), z, dx, dy, dz[i], color=colors[i], zsort='average')

# 設置標題和軸標籤
ax.set_title('3D Bar Chart of Random Data with Column-Based Colors')
ax.set_xlabel('Date')
ax.set_ylabel('Columns (A, B, C, D)')
ax.set_zlabel('Value')

# 設置 y 軸的刻度標籤為 A, B, C, D
ax.set_yticks(np.arange(df.shape[1]))
ax.set_yticklabels(df.columns)

# 顯示圖形
plt.show()

# %%
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# Generate a correlation matrix for the selected columns
corrMatrix = df.corr()

# Plot the correlation matrix using a heatmap
plt.figure(figsize=(10,10))
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
import numpy as np
from scipy import stats
# 三個班學生的成績
group1 = [85, 86, 88, 75, 78, 94]
group2 = [92, 94, 89, 96, 93, 95, 76, 50]
group3 = [78, 81, 79, 84, 77, 80]
# 使用 scipy.stats.f_oneway 進行單因子 ANOVA 檢定
f_statistic, p_value = stats.f_oneway(group1, group2, group3)
# 輸出結果
print("F 統計量:", f_statistic)
print("p-value:", p_value)
# 解釋結果
alpha = 0.05 # 顯著性水平
if p_value < alpha:
  print("拒絕原假設:不同組別之間的均值存在顯著差異。")
else:
  print("未能拒絕原假設:不同組別之間的均值沒有顯著差異。")
# Out:
# F 統計量: 0.5135486690669941
# p-value: 0.6073604385431465
# 未能拒絕原假設:不同組別之間的均值沒有顯著差異。

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
# 創建數據集
data = {
'Score': [85, 86, 88, 75, 78, 94, 92, 94, 89, 96, 93, 95, 78, 81,
79, 84, 77, 80],
'Method': ['A', 'A', 'A', 'A', 'A', 'A', # 教學方法 A
'B', 'B', 'B', 'B', 'B', 'B', # 教學方法 B
'C', 'C', 'C', 'C', 'C', 'C'] # 教學方法 C

}
# 將數據轉換為 DataFrame
df = pd.DataFrame(data)
# 使用 statsmodels 中的 ols 方法進行單因子 ANOVA 分析
model = ols('Score ~ C(Method)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
# 輸出 ANOVA 表
print(anova_table)
# Out:
#                sum_sq    df          F    PR(>F)
# C(Method)  552.111111   2.0  13.848941  0.000391
# Residual   299.000000  15.0        NaN       NaN

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# 創建數據集
data = {
    'Score': [85, 86, 88, 75, 78, 94, 92, 94, 89, 96, 93, 95, 78, 81,
              79, 84, 77, 80],
    'Method': ['A', 'A', 'A', 'A', 'A', 'A',  # 教學方法 A
               'B', 'B', 'B', 'B', 'B', 'B',  # 教學方法 B
               'C', 'C', 'C', 'C', 'C', 'C']  # 教學方法 C
}

# 將數據轉換為 DataFrame
df = pd.DataFrame(data)

# 使用 statsmodels 中的 ols 方法進行單因子 ANOVA 分析
model = ols('Score ~ C(Method)', data=df).fit()  # C(Method) 表示將 'Method' 視為類別變數
anova_table = sm.stats.anova_lm(model, typ=2)  # typ=2 是 ANOVA 表格的類型（對比模型）

# 輸出 ANOVA 表
print(anova_table)
# Out:
#                sum_sq    df          F    PR(>F)
# C(Method)  552.111111   2.0  13.848941  0.000391
# Residual   299.000000  15.0        NaN       NaN
